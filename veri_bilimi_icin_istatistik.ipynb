# %% [markdown]
# ÖRNEK TEORİSİ

# %%
import numpy as np
populasyon=np.random.randint(0,80,10000)
populasyon[0:10]
# Out:
# array([ 2, 17, 78, 53, 37, 78, 49,  4, 51, 56])

# %%
#örneklem çekimi
np.random.seed(115)
orneklem=np.random.choice(a=populasyon,size=100)
orneklem[0:10]
# Out:
# array([25, 34, 15, 39, 33, 25, 39, 31,  6,  9])

# %%
orneklem.mean()
# Out:
# 37.9

# %%
populasyon.mean()
# Out:
# 38.9846

# %% [markdown]
# betimsel istatikler

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
df_tips=tips.copy()
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
# !pip install researchpy
import researchpy as rp

# %%
rp.summary_cont(df_tips[["total_bill","tip","size"]])
# Out:
# /usr/local/lib/python3.10/dist-packages/researchpy/summary.py:60: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ix, df_col in group1.iteritems():
#      Variable      N     Mean      SD      SE  95% Conf.  Interval
# 0  total_bill  244.0  19.7859  8.9024  0.5699    18.6633   20.9086
# 1         tip  244.0   2.9983  1.3836  0.0886     2.8238    3.1728
# 2        size  244.0   2.5697  0.9511  0.0609     2.4497    2.6896

# %%
rp.summary_cat(df_tips[["sex","smoker","day"]])
# Out:
# /usr/local/lib/python3.10/dist-packages/researchpy/summary.py:225: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ix, df_col in group1.iteritems():
#   Variable Outcome  Count  Percent
# 0      sex    Male    157    64.34
# 1           Female     87    35.66
# 2   smoker      No    151    61.89
# 3              Yes     93    38.11
# 4      day     Sat     87    35.66
# 5              Sun     76    31.15
# 6             Thur     62    25.41
# 7              Fri     19     7.79

# %%
#kovaryans
df_tips[["size","total_bill"]].cov()
# Out:
#                 size  total_bill
# size        0.904591    5.065983
# total_bill  5.065983   79.252939

# %%
#korelasyon
df_tips[["size","total_bill"]].corr()
# Out:
#                 size  total_bill
# size        1.000000    0.598315
# total_bill  0.598315    1.000000

# %% [markdown]
# iş uygulaması :fiyat stratejisine karar vermek

# %%
import numpy as np

fiyatlar=np.random.randint(10,110,1000)

# %%
fiyatlar.mean()
# Out:
# 58.822

# %%
#güven aralığı
import statsmodels.stats.api as sms
sms.DescrStatsW(fiyatlar).tconfint_mean()
# Out:
# (57.05297448315257, 60.59102551684744)

# %% [markdown]
# olasılık dağılımları
# bernoulli  dağılımı

# %%
from scipy.stats import bernoulli
p=0.6

# %%
rv=bernoulli(p)
rv.pmf(k=1)
# Out:
# 0.6

# %% [markdown]
# olasılık dağılımları binom dağılımı

# %%
from scipy.stats import binom
p=0.01
n=100

# %%
rv=binom(n,p)
print(rv.pmf(1))
print(rv.pmf(5))
print(rv.pmf(10))
# Out:
# 0.36972963764972666
# 0.002897787123761478
# 7.006035693977194e-08

# %% [markdown]
# olasılık dağılımları poisson dağılımı

# %%
from scipy.stats import poisson
lambda_=0.1
rv=poisson(mu=lambda_)
print(rv.pmf(k=0))
print(rv.pmf(k=3))
print(rv.pmf(k=5))
# Out:
# 0.9048374180359595
# 0.00015080623633932676
# 7.54031181696634e-08
